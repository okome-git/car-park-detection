# %% [markdown]
# # Setup
#
# - Clone repo, install dependencies.
# - check PyTorch and GPU.

# %%
#セットアップ
#gitからリポジトリをコピーし、必要なpipをインストールする

# !git clone https://github.com/okome-git/car-park-detection.git  # clone repo
# %cd car-park-detection
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.11.0+cu113 CPU

# %%
#google driveと接続する

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/data/weights/car_aerial_view.pt .

# %% [markdown]
# # Detect

# %%
#単純検知スクリプト
# !python detect.py --weights car_aerial_view.pt --source ./data/sample/
# Out:
# YOLOv5 🚀 d064a85 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# .....モデル作成中....
# ....................
# image 1/1 /content/car-park-detection/data/sample/sample.jpg: 640x640 11 cars, Done. (0.405s)
# Speed: 2.8ms pre-process, 405.3ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
#単純検知スクリプト(cocoで検出)　
## クラスを指定　https://gist.github.com/AruniRC/7b3dadd004da04c80198557db5da4bda
# !python detect.py --weights car_aerial_view.pt --source ./data/sample/ --classes 3 6 8

# %%
#車体数検知スクリプト
# !python detect_cars_imagefile.py --weights car_aerial_view.pt --source ./data/sample/
# Out:
# YOLOv5 🚀 d064a85 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# .....モデル作成中....
# ....................
# image 1/1 /content/car-park-detection/data/sample/sample.jpg:
# image 1/1 /content/car-park-detection/data/sample/sample.jpg: 640x640 【car　：　11台】(処理時間0.461sec)
# 空：['No1']
# 駐車中：['No2', 'No4', 'No5', 'No3', 'No6']
# 駐車中：['No2', 'No4', 'No5', 'No3', 'No6']
# 空：['No1']
# 判定結果は runs/detect/exp　へ保存しています。

# %% [markdown]
# # その他

# %%
# Re-clone repo
# %cd ..
# %rm -rf car-park-detection && git clone https://github.com/okome-git/car-park-detection.git 
# %cd car-park-detection
# Out:
# /content
# Cloning into 'car-park-detection'...
# remote: Enumerating objects: 177, done.
# remote: Counting objects: 100% (177/177), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 177 (delta 47), reused 160 (delta 36), pack-reused 0
# Receiving objects: 100% (177/177), 1.59 MiB | 26.65 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# /content/car-park-detection
